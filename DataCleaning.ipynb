# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('activities.csv')
data
# Out:
#            date activity  duration  distance     type   user  age gender  \
# 0    01/01/2022      run     53.13      8.90  workout  88898   25      m
# 1    01/01/2022     ride      1.68     49.94  workout  80572   49      m
# 2    01/01/2022     ride      1.94     53.13  workout   3209   43      m
# 3    01/01/2022     ride      1.00     24.15  workout  11053   23      f
# 4    01/01/2022      run     43.10      8.83  workout  99720   16      f
# ..          ...      ...       ...       ...      ...    ...  ...    ...
# 995  28/02/2022      run     53.93      9.33  workout  73342   22      f
# 996  28/02/2022      run     47.27     11.65  workout  16080   22      f
# 997  28/02/2022     ride      1.49     43.07  workout  82189   29      f
# 998  28/02/2022      run     52.93     15.41  workout  46172   44      m
# 999  02/28/2022     ride      1.00     27.30  workout  80572   49      m
#
#      weight             location
# 0      75.4           Lodwar, KE
# ...

# %%
databike = data.loc[data['activity']== 'run', :].min()
sns.relplot(x='duration', y='distance', hue= 'activity', data=data);

# %%
#list for activities for times
duration = data['duration'].tolist()
duration
# Out:
# [53.13,
#  1.68,
#  1.94,
#  1.0,
#  43.1,
#  1.38,
#  1.54,
#  61.07,
#  50.74,
#  43.6,
#  57.97,
#  37.09,
#  26.73,
#  55.3,
#  1.31,
#  1.66,
#  1.67,
#  45.61,
#  1.37,
#  37.48,
#  1.96,
#  34.6,
#  1.29,
#  0.75,
#  39.44,
#  32.04,
#  1.45,
#  43.23,
#  77.06,
#  0.89,
#  0.96,
#  44.37,
#  43.03,
#  43.36,
#  0.99,
#  1.49,
#  1.76,
#  33.99,
#  35.45,
#  1.24,
#  1.18,
#  42.02,
#  1.11,
#  53.22,
#  37.55,
#  50.16,
#  48.24,
#  1.64,
#  1.47,
#  44.09,
#  37.13,
#  1.44,
#  42.3,
#  1.54,
#  1.27,
#  60.49,
#  2.16,
#  46.07,
#  42.27,
#  37.1,
#  1.03,
#  2.02,
#  32.8,
#  43.55,
#  45.62,
#  1.65,
#  2.04,
#  2.06,
#  59.06,
#  1.37,
#  57.77,
#  56.77,
#  1.5,
#  54.37,
#  1.95,
#  52.88,
#  0.71,
#  46.98,
#  1.59,
#  29.4,
#  1.52,
#  1.79,
#  1.17,
#  1.41,
#  1.84,
#  37.41,
#  47.17,
#  1.43,
#  1.06,
#  55.7,
#  1.58,
#  1.33,
#  42.2,
#  1.65,
#  59.32,
#  1.25,
#  1.98,
#  1.18,
#  2.02,
#  1.41,
#  49.08,
#  52.31,
#  1.64,
#  55.68,
#  1.52,
#  38.86,
# ...

# %%
newduration =[]
for datapoint in duration:
    if datapoint<10.00:
        newduration.append(datapoint*60)
    if datapoint>10.00:
        newduration.append(datapoint)
newduration
data['duration']= newduration

# %%
data.loc[data['location']=='?', pd.unique('user')]
# Out:
#       user
# 4    99720
# 5    80370
# 7    46740
# 9    98014
# 11   79805
# ..     ...
# 986  68948
# 989  93860
# 995  73342
# 997  82189
# 998  46172
#
# [367 rows x 1 columns]

# %%
data.loc[data['user']== 16744, :]
# Out:
#      Unnamed: 0        date activity  duration  distance     type   user  age  \
# 99           99  04/01/2022     ride     84.60     40.97  workout  16744   18
# 179         179  07/01/2022     ride     62.40     27.67  workout  16744   18
# 201         201  08/01/2022      run     44.20      6.52  workout  16744   18
# 274         274  11/01/2022     ride     66.60     33.43     race  16744   18
# 282         282  11/01/2022     ride    111.00     57.57  workout  16744   18
# 296         296  12/01/2022      run     43.44      5.85  workout  16744   18
# 406         406  16/01/2022     ride     79.20     35.95  workout  16744   18
# 455         455  18/01/2022     ride    116.40     49.56  workout  16744   18
# 459         459  19/01/2022      run     39.85      5.89  workout  16744   18
# 489         489  20/01/2022     ride     96.00     46.08  workout  16744   18
# 517         517  22/01/2022     ride    111.60     54.65  workout  16744   18
# ...

# %%
data.loc[data['gender']== 'f', 'weight'].mean()
# Out:
# 60.63629764065334

# %%
date = data['date'].tolist()
date
# Out:
# ['01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '01/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '01/02/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
#  '02/01/2022',
# ...

# %%
alldates =[]
for datum in date:
    dat = str(datum)
    number = int(dat[0]) +int(dat[1])
    if number>2 or dat[0]+dat[1]=='10' or dat[0]+dat[1]=='11':
        day= dat[3:5] + '/' + dat[0:3] + dat[6:]
        alldates.append(day)
    else:
        day=dat
        alldates.append(day)

# %%
data['date']= alldates
data.to_csv('datapart1.activities.csv')

# %%
data
# Out:
#            date activity  duration  distance     type   user  age gender  \
# 0    01/01/2022      run     53.13      8.90  workout  88898   25      m
# 1    01/01/2022     ride    100.80     49.94  workout  80572   49      m
# 2    01/01/2022     ride    116.40     53.13  workout   3209   43      m
# 3    01/01/2022     ride     60.00     24.15  workout  11053   23      f
# 4    01/01/2022      run     43.10      8.83  workout  99720   16      f
# ..          ...      ...       ...       ...      ...    ...  ...    ...
# 995  02/28/2022      run     53.93      9.33  workout  73342   22      f
# 996  02/28/2022      run     47.27     11.65  workout  16080   22      f
# 997  02/28/2022     ride     89.40     43.07  workout  82189   29      f
# 998  02/28/2022      run     52.93     15.41  workout  46172   44      m
# 999  02/28/2022     ride     60.00     27.30  workout  80572   49      m
#
#      weight             location
# 0      75.4           Lodwar, KE
# ...
